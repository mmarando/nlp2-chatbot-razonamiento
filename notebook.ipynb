# %%
from agent import *

# %%
def query_razonamiento(question):
    result = solve_complex_question(question)

    print("\n=== Razonamiento intermedio ===")
    for agent_name, reasoning in result["intermediate_reasoning"].items():
        print(f"\n🔹 {agent_name}:")
        print(reasoning)

    print("=== Respuesta final ===")
    print(result["answer"])

    print("\n=== Tokens utilizados ===")
    print(f"- Entrada (prompts): {result['tokens']['input']}")
    print(f"- Salida (respuestas): {result['tokens']['output']}")
    print(f"- Razonamiento (procesamiento interno): {result['tokens']['reasoning']}")
    print(f"- Total: {result['tokens']['total']}")

# %%
# Pregunta que combina química, ingeniería y economía
query_razonamiento("¿Qué avances en baterías de estado sólido podrían hacer viables los vehículos eléctricos de autonomía extendida (>800 km) y cómo impactarían en la industria petrolera?")
# Out:
# === Razonamiento intermedio ===
#
# 🔹 Investigador:
# Como investigador, he recopilado información sobre los avances en baterías de estado sólido que podrían hacer viables los vehículos eléctricos de autonomía extendida (>800 km) y su impacto en la industria petrolera.
#
# **Avances en baterías de estado sólido**
#
# Las baterías de estado sólido (SSB, por sus siglas en inglés) son una tecnología emergente que busca reemplazar los electrolitos líquidos tradicionales en baterías de iones de litio con materiales sólidos. Esto puede ofrecer mejoras significativas en términos de seguridad, energía específica, densidad de energía y ciclo de vida.
#
# Algunos de los avances clave en baterías de estado sólido que podrían hacer viables los vehículos eléctricos de autonomía extendida incluyen:
#
# ...

# %%
# Pregunta que combina legislacion, arte y tecnologia
query_razonamiento("¿Cómo evolucionará el arte generativo con IA en los próximos 5 años frente a las actuales demandas legales por derechos de autor?")
# Out:
# === Razonamiento intermedio ===
#
# 🔹 Investigador:
# Como investigador, he recopilado información sobre el futuro del arte generativo con inteligencia artificial (IA) en los próximos 5 años, considerando las actuales demandas legales por derechos de autor. A continuación, se presentan los datos clave y fuentes:
#
# **Evolución del arte generativo con IA:**
#
# 1. **Mayor accesibilidad y democratización**: En los próximos 5 años, se espera que la tecnología de IA para el arte generativo se vuelva más accesible y asequible para artistas, diseñadores y no expertos. Esto llevará a una mayor democratización de la creación de arte generativo. (Fuente: Adobe, "The Future of Art and Design with AI")
# 2. **Avances en la calidad y realismo**: La IA continuará mejorando en términos de calidad y realismo, lo que permitirá a los artistas generar obras más convincentes y detalladas. (Fuente: NVIDIA, "AI-Generated Art: A New Creative Frontier")
# ...
